# %%
example={"key1": "value1", "key2": "value2"}

# %%
example["key1"]
# Out:
# 'value1'

# %%
example.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 example.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
#%pip install --upgrade python-box
from box.config_box import ConfigBox

# %%
example=ConfigBox({"key1": "value1", "key2": "value2"})
example.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int) -> int:
    return x * y

# %%
get_product(3, 4)
# Out:
# 12

# %%
get_product(3, "5")
# Out:
# '555'

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x:int, y:int) -> int:
    return x * y

# %%
get_product(3, "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 get_product(3, "4")
#
# File ~/Desktop/DSRepo/venv/lib/python3.12/site-packages/ensure/main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x104b705e0> does not match annotation type <class 'int'>
